# %% [markdown]
# # limpieza y transformacion de datos
#
# trabajamos con BBDD de empleados que tiene valoress nulos. Debes:
#
#     1- rellenar los salarios faltantes Nan¡N con el salario medio de resto de la plantilla.
#     2- eliminar las filas donde departamento sea nulo.
#     3- crear una nueva columna salaio_anual multiplicando el salario mensual por 12

# %%
import pandas as pd
import numpy as np

# %%
datos_empleados = {
    'Nombre': ['Juan', 'Sara', 'Pedro', 'Laura', 'Mike'],
    'Departamento': ['IT', 'Ventas', np.nan, 'IT', 'Marketing'],
    'Salario_Mensual': [2000, np.nan, 1800, 2500, np.nan]
}

df_empleados = pd.DataFrame(datos_empleados)
df_empleados
